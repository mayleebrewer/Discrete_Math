# %% [markdown]
# <a href="https://colab.research.google.com/github/mayleebrewer/Discrete_Math/blob/main/BrewerMaylee_3133_Mod2_Probablility.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part 3# : CPSMA 3133 [Dr. Lynam's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Spinner Probability
#
# ### Maylee Brewer 262854

# %% [markdown]
# ## 1 Probability
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# My sample space is the possible outcomes of a colored spinner.
# There will be 6 different colors.
#
# Green: 1/4
# Blue: 1/4
# Red: 1/4
# Yellow: 1/4

# %%
p=[1/4,1/4,1/4,1/4]
sum(p)
# Out:
# 1.0

# %% [markdown]
# # Compound event

# %% [markdown]
# For my comound event we are going to see what the probability is for spinning two blues in a row. Since this will be equally likely on each of the two spins this should give us 4*4=16 possible outcomes.

# %%
p= [(1/4)*(1/4)]
sum(p)
# Out:
# 0.0625

# %% [markdown]
# So there is a 0.0625 chance that we will spin a blue twice in a row!

# %% [markdown]
# ## Union and intersection

# %% [markdown]
# First we will start with the union of the Probability of spinning a blue or a red.

# %% [markdown]
# $$u={p(B)+p(R)-P(B\cap R)}$$

# %%
u={(1/4)+(1/4)-(1/16)}
sum(u)
# Out:
# 0.4375

# %% [markdown]
# That's funny because I figured to would be a .5 probability!
#
# Now for the intersection (Which I kind of already gave away). This is the probablity for either spinning a blue and red.

# %%
i=[(1/4)*(1/4)]
sum(i)
# Out:
# 0.0625

# %% [markdown]
# This next part was a little tricky. We are going to split the spinner in half and say that the right side is blue and red and the left side is yellow and green. Now let's say that
#
# P(B)= the probability of the spinner landing on blue
#
# P(R)= the probability of the spinner landing on the right side
#
# P(B|R)= the probability of B given R
#
# P(R|B)= the Probabilty of R given B
#
# P(B∩R)= the probability of both.

# %%
#P(B\capR)
I={(1/4)*(1/2)}
sum(I)
# Out:
# 0.125

# %%
#P(B|R)
R=[((1/2)*(1/4))/(1/2)]
sum(R)
# Out:
# 0.25

# %%
#P(R|B)
B=[((1/4)*(1/2))/(1/4)]
sum(B)
# Out:
# 0.5

# %%
#Bayes Theorem P(B|P)
T={((1/4)*(0.5)) /(1/2)}
sum(T)
# Out:
# 0.25

# %% [markdown]
# As you can see bayes theorem  held up!

# %% [markdown]
# Now we will do the complement! The probability that the spinner will not land on a blue.

# %%
c= {1-.25}
sum(c)
# Out:
# 0.75

# %% [markdown]
# Now we will do a simple random simulation of the resukt of the spinner.

# %%
from random import choices


choices(['Blue','Red','Yellow','Green'],k=10)
# Out:
# ['Blue',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Blue',
#  'Green',
#  'Red',
#  'Red']

# %% [markdown]
# GREEN! Crazy how much green we spun! I would say that doing this only ten times made the number pretty off but i bet if we did it more time they would be closer!
#
# This was a fun project! I like probability a lot more than I used to!
