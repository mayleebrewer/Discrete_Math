# %% [markdown]
# # Project Part #1 : CPSMA 3133 [Dr. Lynam's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Sets
#
# ### Maylee Brewer 262854

# %% [markdown]
# ## 1 Sets

# %% [markdown]
# I will be doing a Mario Kart theme for my project because it is my favorite video game and it has the best characters.
#
# ![image.png](data:image/png;base64,...)
#
# Set ***64*** will be the charaters from Mario Kart 64. Set ***Wii*** will be the charaters from Mario Kart 64 and set ***8*** from Mario Kart deluxe 8.

# %%
# Create a set of string type
set_1 =  {'Mario', 'Luigi', 'Boswer', 'Yoshi', 'Wario', 'Toad', 'Princess Peach'}
print('64:', set_1 )
set_2 =  {'Mario', 'Luigi', 'Princess Peach', 'Toad', 'Yoshi', 'Wario', 'Boswer', 'Baby Mario', 'Diddy Kong' }
print('Wii:',set_2)
set_3 =  {'Mario', 'Luigi', 'Princess Peach', 'Toad', 'Yoshi', 'Wario', 'Boswer', 'Metal Mario', 'Baby Mario', 'Shy Guy', 'Boswer Jr.', 'Cat Peach'}
print('8:', set_3)
set_4 = {'Mario','Luigi', 'Princess Peach', 'Toad', 'Yoshi','Wario', 'Boswer', "Baby Mario", 'Diddy Kong', 'Shy Guy', 'Metal Mario', 'Boswer Jr.', 'Cat Peach', 'Kamek', 'Donkey Kong Jr.','Wiggler', 'Peachette', 'Petey Piranha'   }
print('U:', set_4)
# Out:
# 64: {'Princess Peach', 'Boswer', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Toad'}
# Wii: {'Princess Peach', 'Boswer', 'Baby Mario', 'Yoshi', 'Mario', 'Luigi', 'Diddy Kong', 'Wario', 'Toad'}
# 8: {'Princess Peach', 'Boswer', 'Baby Mario', 'Yoshi', 'Mario', 'Luigi', 'Metal Mario', 'Cat Peach', 'Shy Guy', 'Wario', 'Toad', 'Boswer Jr.'}
# U: {'Princess Peach', 'Boswer', 'Baby Mario', 'Wiggler', 'Yoshi', 'Donkey Kong Jr.', 'Mario', 'Peachette', 'Luigi', 'Diddy Kong', 'Metal Mario', 'Petey Piranha', 'Cat Peach', 'Shy Guy', 'Wario', 'Toad', 'Kamek', 'Boswer Jr.'}

# %% [markdown]
# It took me a second to figure out how to make it look nice.
#
# I left out a few characters on Wii and 8.
#
# The universal set U will be all of the characters in the Mario Kart universe. My favorite charater is Yoshi!
#
# ![Screenshot 2023-01-13 215629.png](data:image/png;base64,...)
#
# I did a union here is the unions and intersections of each set.  It was way eaiser to just do the union and intersection functions instead of retyping each charater. Plus it made sure I didn't miss any charaters!

# %%
# preform union operation using ()
print('64.union(Wii):', set_1.union(set_2))
print('64.union(8):', set_1.union(set_3))
print('Wii.union(8):', set_2.union(set_3))

# Preform intersection operation using ()
print('64.intersection(Wii):', set_1.intersection(set_2))
print('64.intersection(8):', set_1.intersection(set_3))
print('Wii.intersection(8):', set_2.intersection(set_3))
# Out:
# 64.union(Wii): {'Boswer', 'Baby Mario', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Princess Peach', 'Diddy Kong', 'Toad'}
# 64.union(8): {'Boswer', 'Baby Mario', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Shy Guy', 'Cat Peach', 'Princess Peach', 'Metal Mario', 'Toad', 'Boswer Jr.'}
# Wii.union(8): {'Boswer', 'Baby Mario', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Shy Guy', 'Cat Peach', 'Princess Peach', 'Diddy Kong', 'Metal Mario', 'Toad', 'Boswer Jr.'}
# 64.intersection(Wii): {'Princess Peach', 'Boswer', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Toad'}
# 64.intersection(8): {'Princess Peach', 'Boswer', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Toad'}
# Wii.intersection(8): {'Princess Peach', 'Boswer', 'Baby Mario', 'Yoshi', 'Mario', 'Luigi', 'Wario', 'Toad'}

# %% [markdown]
# Here I did the union and intercection of characters from the sets. It was cool to see how they started with the orignal characters and added different ones to the new versions. I do not think there is any difference in which set is called first because the order of a set is not important.

# %% [markdown]
# It was hard finding characters that were not in Wii or 8 mario kart. The ones I have never heard of before but I promise I didn't make them up!
#
# Here are the complements of each set. I could not figure out how to code the complement so I just did the difference between the universal and each set and I think it worked.

# %%
#preform difference operation using ()
print('U.complement(64)', set_4-set_1)

#preform difference operation using ()
print('U.complement(Wii)', set_4-set_2)

#preform difference operation using ()
print('U.complement(8)', set_4-set_3)
# Out:
# U.complement(64) {'Baby Mario', 'Donkey Kong Jr.', 'Peachette', 'Diddy Kong', 'Metal Mario', 'Petey Piranha', 'Shy Guy', 'Wiggler', 'Boswer Jr.', 'Kamek', 'Cat Peach'}
# U.complement(Wii) {'Donkey Kong Jr.', 'Peachette', 'Petey Piranha', 'Metal Mario', 'Shy Guy', 'Wiggler', 'Boswer Jr.', 'Kamek', 'Cat Peach'}
# U.complement(8) {'Donkey Kong Jr.', 'Peachette', 'Petey Piranha', 'Diddy Kong', 'Wiggler', 'Kamek'}

# %% [markdown]
# Set 64 is actually a subset of Set Wii and Set 8. Obviously Set 64, Wii, and 8 are all subsets of set U.

# %% [markdown]
# ## Power set

# %% [markdown]
# Here is the power set of the the first set, ***64***.

# %%
def DPpowerset(s):
  powerset = [[]]
  for i in s:
    for sett in powerset:
      powerset = powerset + [sett + [i]]
  return powerset

# %%
DPpowerset(set_1)
# Out:
# [[],
#  ['Princess Peach'],
#  ['Boswer'],
#  ['Princess Peach', 'Boswer'],
#  ['Yoshi'],
#  ['Princess Peach', 'Yoshi'],
#  ['Boswer', 'Yoshi'],
#  ['Princess Peach', 'Boswer', 'Yoshi'],
#  ['Mario'],
#  ['Princess Peach', 'Mario'],
#  ['Boswer', 'Mario'],
#  ['Princess Peach', 'Boswer', 'Mario'],
#  ['Yoshi', 'Mario'],
#  ['Princess Peach', 'Yoshi', 'Mario'],
#  ['Boswer', 'Yoshi', 'Mario'],
#  ['Princess Peach', 'Boswer', 'Yoshi', 'Mario'],
#  ['Luigi'],
#  ['Princess Peach', 'Luigi'],
#  ['Boswer', 'Luigi'],
#  ['Princess Peach', 'Boswer', 'Luigi'],
#  ['Yoshi', 'Luigi'],
#  ['Princess Peach', 'Yoshi', 'Luigi'],
#  ['Boswer', 'Yoshi', 'Luigi'],
#  ['Princess Peach', 'Boswer', 'Yoshi', 'Luigi'],
#  ['Mario', 'Luigi'],
#  ['Princess Peach', 'Mario', 'Luigi'],
#  ['Boswer', 'Mario', 'Luigi'],
#  ['Princess Peach', 'Boswer', 'Mario', 'Luigi'],
#  ['Yoshi', 'Mario', 'Luigi'],
#  ['Princess Peach', 'Yoshi', 'Mario', 'Luigi'],
#  ['Boswer', 'Yoshi', 'Mario', 'Luigi'],
# ...

# %% [markdown]
# It was really fun to see the what characters belonged to each set. I found that while Mario kart 8 deluxe had the most characters there was still one that Wii had that 8 did not have.
#
# I did not code the the complement correctly but I think by using the differnce of the universal set and one of the other sets got me the answer I needed for the complement. I think finding the power set by hand would be horrible. I am very glad python can do all of that work for me!
