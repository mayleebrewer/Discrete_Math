# %% [markdown]
# <a href="https://colab.research.google.com/github/mayleebrewer/Discrete_Math/blob/main/BrewerMaylee_CPSMA_3913_Module4_Counting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # : CPSMA 3133 [Dr. Lynams's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Counting
#
# ### Maylee Brewer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##  10 events with 20 outcomes

# %% [markdown]
#  For my simulation I will be continuing the study of the game spinner. I'll add a few more colors to the spinner as it will work for this situation. First i will add a few packages.

# %%
import math
from sympy import *
x = symbols('x')

# %% [markdown]
# A) Now I will see how many out comes were possible in the situation if we spun the spinner 10 times.

# %%
20**10
# Out:
# 1048576

# %% [markdown]
# B) Now we will be doing the outcomes if order does not matter so we will use the $nCk$ formula.

# %%
import math

math.factorial(20)/(math.factorial(10)*math.factorial(10))
# Out:
# 184756.0

# %% [markdown]
# C)Now if order does matter we will use the $nPr$ formula

# %%
math.factorial(20)/(math.factorial(10))
# Out:
# 670442572800.0

# %% [markdown]
# D) We want to find the coefficient of the 5th order of $(x-3)^9$

# %%
coefficient = (-3)**(9 - 5) * math.comb(9, 5)
print(coefficient)
# Out:
# 10206

# %% [markdown]
# # Reflection

# %% [markdown]
# I learned a lot about counting during this section. I never knew how complicated it could get. I think I got everything coded. I  had to look the last on up because I was not sure about it but I think I've got it now. All of the outcomes are different because when we added different rules, like the order, it changes the problem.
