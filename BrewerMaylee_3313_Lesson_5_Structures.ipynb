# %% [markdown]
# <a href="https://colab.research.google.com/github/mayleebrewer/Discrete_Math/blob/main/BrewerMaylee_3313_Lesson_5_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #5 : CPSMA 3133 [Dr. Lynam's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Structures
#
# ### Maylee Brewer 262854

# %% [markdown]
# ## 1 Graphs and Trees

# %%
map

# %% [markdown]
# a/b)I am going to do the different job I have had in my life so far.

# %%
import graphviz

dot = graphviz.Digraph(comment='')
dot.node('A', 'Subway')
dot.node('B', 'Bursars office')
dot.node('L', 'Church Camp')
dot.node('M', 'Tutoring')
dot.node('R', 'Worship leader')

dot.edges(['AB', 'BL','BR','RL','LB','BM','RM','LR','LB'])
dot.edge( 'B', 'L', constraint='Summer job')
dot

# %% [markdown]
# So I started at Subway when I was in high school and then when I came to college I started working at the Bursar's Office. Then during the summer I worked at a church camp and came back to the Bursar's office. I got a second job as a worship leader and I did both for a while. After working at camp for a second summer I came back to my two jobs then quit both to do tutoring. Crazy times!

# %% [markdown]
# c)My paths are directed since it is a time line and I never went back to work at Subway and I am only doing tutoring now.

# %% [markdown]
# d)The degree of vertex "Subway" is 1 since there is only one edge on it since I was my ifrst job and I never went back to it or left it for more than one job.

# %% [markdown]
# e)There is no cycle in my stucture because I have never left a job and went back to the same one, I think that would be the only way I could have a cycle in my graph

# %% [markdown]
# I think I covered everything!
# I promise my job changing was not as crazy as it looks!
